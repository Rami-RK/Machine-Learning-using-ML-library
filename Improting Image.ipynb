# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
i = Image.open('Mahadev.jpg')
iar = np.asarray(i)
print(iar)
# Out:
# [[[248 248 248]
#   [248 248 248]
#   [248 248 248]
#   ...
#   [248 248 248]
#   [248 248 248]
#   [247 247 247]]
#
#  [[248 248 248]
#   [248 248 248]
#   [248 248 248]
#   ...
#   [247 247 247]
#   [246 246 246]
#   [246 246 246]]
#
#  [[248 248 248]
#   [248 248 248]
#   [248 248 248]
#   ...
#   [247 247 247]
#   [247 247 247]
#   [246 246 246]]
#
#  ...
#
#  [[221 221 221]
#   [221 221 221]
#   [221 221 221]
#   ...
#   [218 218 218]
#   [218 218 218]
#   [218 218 218]]
#
#  [[220 220 220]
#   [220 220 220]
#   [221 221 221]
#   ...
#   [218 218 218]
#   [218 218 218]
#   [217 217 217]]
#
#  [[221 221 221]
#   [220 220 220]
#   [220 220 220]
#   ...
#   [218 218 218]
#   [218 218 218]
#   [217 217 217]]]

# %%
plt.imshow(iar,cmap=plt.cm.binary)
plt.axis('off')
plt.show()

# %%
flat_arr = iar.ravel()
# convert it to a matrix
vector = np.matrix(flat_arr)

# %%
flat_arr
# Out:
# array([248, 248, 248, ..., 217, 217, 255], dtype=uint8)

# %%
vector
# Out:
# matrix([[248, 248, 248, ..., 217, 217, 255]], dtype=uint8)
